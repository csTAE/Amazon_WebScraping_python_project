# %% [markdown]
# <a href="https://colab.research.google.com/github/csTAE/Amazon_WebScraping_python_project/blob/main/Web_scraping2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL = "https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1653308124&sprefix=ba%2Caps%2C283&ref=sr_pg_1"

# %%
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36','Accept-Language':'en-US,en;q=0.5'})

# %%
webpage = requests.get(URL, headers=HEADERS)

# %%
type(webpage.content)
# Out:
# bytes

# %%
soup = BeautifulSoup(webpage.content, 'html.parser')

# %%
links = soup.find_all("a",attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# %%
link = links[0].get('href')

# %%
product_list = "https://amazon.com" + link

# %%
product_list
# Out:
# 'https://amazon.com/American-Tourister-AMT-SCH-02/dp/B07CJCGM1M/ref=sr_1_1?crid=2M096C61O4MLT&keywords=bags&qid=1679482415&sprefix=ba%2Caps%2C283&sr=8-1'

# %%
new_webpage = requests.get(URL, headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

# %%
new_soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
new_soup.find_all("span", attrs={"class":'a-size-medium a-color-base a-text-normal'})
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">American Tourister 32 Ltrs Black Casual Backpack (AMT FIZZ SCH BAG 02 - BLACK)</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Wesley Milestone 2.0 Casual Waterproof Laptop Backpack/Office Bag/School Bag/College Bag/Business Bag/Travel Backpack (Dimensions:13x18 inches) (Compatible with 39.62cm(15.6inch laptop) 30 L (Blue &amp; black)</span>,
#  <span class="a-size-medium a-color-base a-text-normal">ADISA 15.6 inch Laptop Backpack Office Bag College Travel Back Pack 32 Ltrs (z-Navy Blue)</span>,
#  <span class="a-size-medium a-color-base a-text-normal">uppercase Medium 17 Ltrs Vegan Leather (upto 14 inch) Laptop Backpack 2300EBP1 3x more water resistant sustainable bags with rain proof zippers for Men, Women, Boys and Girls, 750 Days warranty</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Skybags Brat Black 46 Cms Casual Backpack</span>,
# ...

# %%
new_soup.find_all("span", attrs={"class":'a-price a-text-price'})
# Out:
# [<span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">₹2,300</span><span aria-hidden="true">₹2,300</span></span>,
#  <span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">₹1,199</span><span aria-hidden="true">₹1,199</span></span>,
#  <span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">₹1,799</span><span aria-hidden="true">₹1,799</span></span>,
#  <span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">₹2,100</span><span aria-hidden="true">₹2,100</span></span>,
#  <span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">₹3,895</span><span aria-hidden="true">₹3,895</span></span>,
# ...

# %%
new_soup.find_all("span", attrs={"class":'a-icon-alt'})
# Out:
# [<span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.3 out of 5 stars</span>,
#  <span class="a-icon-alt">3.8 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.1 out of 5 stars</span>,
#  <span class="a-icon-alt">3.9 out of 5 stars</span>,
#  <span class="a-icon-alt">3.7 out of 5 stars</span>,
#  <span class="a-icon-alt">3.7 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">3.9 out of 5 stars</span>,
#  <span class="a-icon-alt">3.9 out of 5 stars</span>,
#  <span class="a-icon-alt">3.8 out of 5 stars</span>,
#  <span class="a-icon-alt">3.9 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.2 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
# ...

# %%
dataframe={'Title':}
